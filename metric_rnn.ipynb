# %%
import os
import torch
import numpy as np
from PIL import Image
from pytorch_msssim import ms_ssim
import matplotlib.pyplot as plt
import pandas as pd

from pytorch_msssim import ssim, ms_ssim
from util.metric import MultiScaleSSIM, psnr

# %%
# 파라미터
png_folder = 'data/kodim/png'
rnn_folder = 'data/kodim/rnn'
model_path = 'checkpoint/tiny-imagenet-200-ConvGRUCell/batch32-lr0.0005-l1-06_17_18_02/_best_model_epoch_0188.pth'
reconstruction_metohod = 'one_shot'
rnn_model = 'ConvGRUCell'

if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

# %%
# 바뀌지 않는 세팅
png_images_path = os.listdir(png_folder)
png_images_path.sort()

rnn_images_path = os.listdir(rnn_folder)
rnn_images_path.sort()

iters = range(1, 33)
results_dict = {sampling: [] for sampling in iters}
codes_dict = {}
decoded_images_dict = {}

if rnn_model == 'ConvGRUCell':
    from modules import GRU_network as network
else:
    from modules import LSTM_network as network

print('','='*120,'\n ||\tdevice: {}\n'.format(device), "="*120, "\n")
decoder = network.DecoderCell().to(device)
decoder.eval()

checkpoint = torch.load(model_path)
decoder.load_state_dict(checkpoint['decoder'])
# Out:
#  ========================================================================================================================
#  ||	device: cuda
#  ========================================================================================================================
# <All keys matched successfully>

# %%
# image 및 codes 로드
png_images = {}
for file_name in png_images_path:
    if file_name.lower().endswith('.png'):
        png_path = os.path.join(png_folder, file_name)
        codes_dict[file_name.split('.')[0]] = []
        decoded_images_dict[file_name.split('.')[0]] = []
        with Image.open(png_path) as img:
            png_images[file_name.split('.')[0]] = np.array(img).transpose(2, 0, 1)

for file_name in rnn_images_path:
    if file_name.lower().endswith('.npz'):
        npz_path = os.path.join(rnn_folder, file_name)
        with np.load(npz_path) as data:
            codes_dict[file_name.split('_')[0]].append([data['shape'], data['codes']])
            # print(npz_path, data['shape'], data['codes'].shape) # >> 32*32*48 / 6144 = 8 -> 즉 code는 8비트, 32, 32이니 실제로는 4, 4패치

# %%
# MS-SSIM 계산
for k in codes_dict.keys(): # k = 'kodim01' 등의 키
    content = codes_dict[k] # 각 이미지에 대한 content, content[0~32]는 각각 iter, content[i][0~1]은 각각 shape, codes
    print("[decode process] image: ", k)
    # for i in range(len(content)): # i = 1~32의 각 iter
    codes = np.unpackbits(content[-1][1])
    codes = np.reshape(codes, content[-1][0]).astype(np.float32) * 2 - 1

    codes = torch.from_numpy(codes)
    iters, batch_size, channels, height, width = codes.size()
    height = height * 16
    width = width * 16

    with torch.no_grad():
        if rnn_model == 'ConvGRUCell':
            # init gru state
            decoder_h_1 = (torch.zeros(batch_size, 512, height // 16, width // 16)).to(device)
            decoder_h_2 = (torch.zeros(batch_size, 512, height // 8, width // 8)).to(device)
            decoder_h_3 = (torch.zeros(batch_size, 256, height // 4, width // 4)).to(device)
            decoder_h_4 = (torch.zeros(batch_size, 128, height // 2, width // 2)).to(device)
        else:
            ## init lstm state
            decoder_h_1 = (torch.zeros(batch_size, 512, height // 16, width // 16), torch.zeros(batch_size, 512, height // 16, width // 16)).to(device)
            decoder_h_2 = (torch.zeros(batch_size, 512, height // 8, width // 8), torch.zeros(batch_size, 512, height // 8, width // 8)).to(device)
            decoder_h_3 = (torch.zeros(batch_size, 256, height // 4, width // 4), torch.zeros(batch_size, 256, height // 4, width // 4)).to(device)
            decoder_h_4 = (torch.zeros(batch_size, 128, height // 2, width // 2), torch.zeros(batch_size, 128, height // 2, width // 2)).to(device)

        codes = codes.to(device)
        image = torch.zeros(1, 3, height, width) + 0.5

        for iters in range(iters):
            output, decoder_h_1, decoder_h_2, decoder_h_3, decoder_h_4 = decoder(
                codes[iters], decoder_h_1, decoder_h_2, decoder_h_3, decoder_h_4)
            image = image + output.data.cpu()
            image_disp = np.squeeze(image[0].numpy().clip(0, 1) * 255.0).astype(np.uint8).transpose(1, 2, 0)
            decoded_images_dict[k].append([k, iters+1, image_disp])

            # print("[] iter: ", iters + 1, )
            # plt.figure(figsize=(10, 5))
            # plt.subplot(1, 2, 1)
            # # plt.imshow(image_org.transpose(1, 2, 0))
            # # plt.title('Org Image')
            # plt.subplot(1, 2, 2)
            # plt.imshow(image_disp)
            # plt.title('Decoded Image')
            # plt.show()
# Out:
# [decode process] image:  kodim01
# [decode process] image:  kodim02
# [decode process] image:  kodim03
# [decode process] image:  kodim04
# [decode process] image:  kodim05
# [decode process] image:  kodim06
# [decode process] image:  kodim07
# [decode process] image:  kodim08
# [decode process] image:  kodim09
# [decode process] image:  kodim10
# [decode process] image:  kodim11
# [decode process] image:  kodim12
# [decode process] image:  kodim13
# [decode process] image:  kodim14
# [decode process] image:  kodim15
# [decode process] image:  kodim16
# [decode process] image:  kodim17
# [decode process] image:  kodim18
# [decode process] image:  kodim19
# [decode process] image:  kodim20
# [decode process] image:  kodim21
# [decode process] image:  kodim22
# [decode process] image:  kodim23
# [decode process] image:  kodim24

# %%
# 이제 png_images 딕셔너리 안에 kodim01 ~ 24까지의 이미지가 있고, decoded_images_dict 딕셔너리 안에도 같은 이미지가 있다.
# decoded_images_dict의 value는 [key값, iter, image]로 구성되어 있다.
results_dict = {}
for i in range(1, 33):
    results_dict[i] = []

for k in png_images.keys():
    org_image = np.expand_dims(png_images[k], axis=0)
    print("[calculate metric] image: ", k)
    for i in range(len(decoded_images_dict[k])):
        decoded_images = decoded_images_dict[k][i][2].transpose(2, 0, 1)
        decoded_images = np.expand_dims(decoded_images, axis=0)
        
        ms_ssim_score = MultiScaleSSIM(org_image, decoded_images, max_val=255)
        psnr_score = psnr(org_image, decoded_images)

        path = os.path.join(rnn_folder, f"{k}_iter{i+1:02}.npz")
        rnn_size = os.path.getsize(path) * 8
        bpp = rnn_size / (decoded_images.shape[2] * decoded_images.shape[3])

        results_dict[i+1].append([i, bpp, ms_ssim_score, psnr_score])
        print(f"iter: {i+1:02} | bpp: {bpp:.4f} | MS-SSIM: {ms_ssim_score:.4f} | PSNR: {psnr_score:.4f}")
        # print("org_image: ", org_image.shape, " | decoded_image: ", decoded_images_dict[k][i][2].shape)
# Out:
# iter: 01 | bpp: 0.1211 | MS-SSIM: 0.9350 | PSNR: 29.1437
# iter: 02 | bpp: 0.2461 | MS-SSIM: 0.9599 | PSNR: 29.9152
# iter: 03 | bpp: 0.3717 | MS-SSIM: 0.9674 | PSNR: 30.3689
# iter: 04 | bpp: 0.4967 | MS-SSIM: 0.9728 | PSNR: 30.7422
# iter: 05 | bpp: 0.6217 | MS-SSIM: 0.9770 | PSNR: 31.0725
# iter: 06 | bpp: 0.7468 | MS-SSIM: 0.9797 | PSNR: 31.4124
# iter: 07 | bpp: 0.8718 | MS-SSIM: 0.9828 | PSNR: 31.7220
# iter: 08 | bpp: 0.9968 | MS-SSIM: 0.9850 | PSNR: 32.0560
# iter: 09 | bpp: 1.1219 | MS-SSIM: 0.9869 | PSNR: 32.3548
# iter: 10 | bpp: 1.2469 | MS-SSIM: 0.9886 | PSNR: 32.6732
# iter: 11 | bpp: 1.3720 | MS-SSIM: 0.9898 | PSNR: 32.9645
# iter: 12 | bpp: 1.4970 | MS-SSIM: 0.9908 | PSNR: 33.2584
# iter: 13 | bpp: 1.6219 | MS-SSIM: 0.9916 | PSNR: 33.5258
# iter: 14 | bpp: 1.7471 | MS-SSIM: 0.9925 | PSNR: 33.8468
# iter: 15 | bpp: 1.8721 | MS-SSIM: 0.9932 | PSNR: 34.1476
# iter: 16 | bpp: 1.9971 | MS-SSIM: 0.9937 | PSNR: 34.4324
# iter: 17 | bpp: 2.0732 | MS-SSIM: 0.9932 | PSNR: 34.1569
# iter: 18 | bpp: 2.1753 | MS-SSIM: 0.9929 | PSNR: 34.1178
# iter: 19 | bpp: 2.3001 | MS-SSIM: 0.9931 | PSNR: 34.1416
# iter: 20 | bpp: 2.4218 | MS-SSIM: 0.9930 | PSNR: 34.1044
# iter: 21 | bpp: 2.5403 | MS-SSIM: 0.9930 | PSNR: 34.1235
# iter: 22 | bpp: 2.6633 | MS-SSIM: 0.9931 | PSNR: 34.1465
# iter: 23 | bpp: 2.7843 | MS-SSIM: 0.9930 | PSNR: 34.0634
# iter: 24 | bpp: 2.9082 | MS-SSIM: 0.9930 | PSNR: 34.0512
# iter: 25 | bpp: 3.0300 | MS-SSIM: 0.9929 | PSNR: 33.9529
# iter: 26 | bpp: 3.1549 | MS-SSIM: 0.9928 | PSNR: 33.8834
# iter: 27 | bpp: 3.2790 | MS-SSIM: 0.9927 | PSNR: 33.8324
# iter: 28 | bpp: 3.4025 | MS-SSIM: 0.9926 | PSNR: 33.7714
# iter: 29 | bpp: 3.5254 | MS-SSIM: 0.9924 | PSNR: 33.6738
# iter: 30 | bpp: 3.6496 | MS-SSIM: 0.9924 | PSNR: 33.5723
# iter: 31 | bpp: 3.7721 | MS-SSIM: 0.9922 | PSNR: 33.4355
# iter: 32 | bpp: 3.8957 | MS-SSIM: 0.9920 | PSNR: 33.3344
# iter: 01 | bpp: 0.0854 | MS-SSIM: 0.9907 | PSNR: 30.0728
# iter: 02 | bpp: 0.2017 | MS-SSIM: 0.9937 | PSNR: 31.4242
# iter: 03 | bpp: 0.3177 | MS-SSIM: 0.9961 | PSNR: 33.1023
# iter: 04 | bpp: 0.4432 | MS-SSIM: 0.9970 | PSNR: 33.7149
# iter: 05 | bpp: 0.5670 | MS-SSIM: 0.9976 | PSNR: 34.3811
# iter: 06 | bpp: 0.6922 | MS-SSIM: 0.9980 | PSNR: 34.8315
# iter: 07 | bpp: 0.8172 | MS-SSIM: 0.9983 | PSNR: 35.3104
# iter: 08 | bpp: 0.9422 | MS-SSIM: 0.9985 | PSNR: 35.7015
# iter: 09 | bpp: 1.0673 | MS-SSIM: 0.9987 | PSNR: 36.0988
# iter: 10 | bpp: 1.1923 | MS-SSIM: 0.9989 | PSNR: 36.4837
# iter: 11 | bpp: 1.3173 | MS-SSIM: 0.9990 | PSNR: 36.8183
# iter: 12 | bpp: 1.4424 | MS-SSIM: 0.9991 | PSNR: 37.1299
# iter: 13 | bpp: 1.5674 | MS-SSIM: 0.9991 | PSNR: 37.3851
# iter: 14 | bpp: 1.6924 | MS-SSIM: 0.9992 | PSNR: 37.6699
# iter: 15 | bpp: 1.8175 | MS-SSIM: 0.9993 | PSNR: 37.9388
# iter: 16 | bpp: 1.9425 | MS-SSIM: 0.9993 | PSNR: 38.1630
# iter: 17 | bpp: 2.0024 | MS-SSIM: 0.9992 | PSNR: 37.9358
# iter: 18 | bpp: 2.1002 | MS-SSIM: 0.9992 | PSNR: 37.9148
# iter: 19 | bpp: 2.2236 | MS-SSIM: 0.9992 | PSNR: 37.9254
# iter: 20 | bpp: 2.3389 | MS-SSIM: 0.9992 | PSNR: 37.8837
# iter: 21 | bpp: 2.4488 | MS-SSIM: 0.9992 | PSNR: 37.8737
# iter: 22 | bpp: 2.5692 | MS-SSIM: 0.9992 | PSNR: 37.8411
# iter: 23 | bpp: 2.6726 | MS-SSIM: 0.9992 | PSNR: 37.6993
# iter: 24 | bpp: 2.7909 | MS-SSIM: 0.9992 | PSNR: 37.5886
# iter: 25 | bpp: 2.9024 | MS-SSIM: 0.9992 | PSNR: 37.4487
# iter: 26 | bpp: 3.0148 | MS-SSIM: 0.9991 | PSNR: 37.3440
# iter: 27 | bpp: 3.1327 | MS-SSIM: 0.9991 | PSNR: 37.2025
# iter: 28 | bpp: 3.2399 | MS-SSIM: 0.9991 | PSNR: 37.0462
# iter: 29 | bpp: 3.3403 | MS-SSIM: 0.9991 | PSNR: 36.8170
# iter: 30 | bpp: 3.4569 | MS-SSIM: 0.9990 | PSNR: 36.5908
# iter: 31 | bpp: 3.5679 | MS-SSIM: 0.9990 | PSNR: 36.3929
# iter: 32 | bpp: 3.6777 | MS-SSIM: 0.9990 | PSNR: 36.2091
# iter: 01 | bpp: 0.1014 | MS-SSIM: 0.9736 | PSNR: 30.6454
# iter: 02 | bpp: 0.2217 | MS-SSIM: 0.9860 | PSNR: 32.7110
# iter: 03 | bpp: 0.3426 | MS-SSIM: 0.9927 | PSNR: 34.4498
# iter: 04 | bpp: 0.4665 | MS-SSIM: 0.9949 | PSNR: 35.3314
# iter: 05 | bpp: 0.5914 | MS-SSIM: 0.9959 | PSNR: 35.9246
# iter: 06 | bpp: 0.7161 | MS-SSIM: 0.9966 | PSNR: 36.4405
# iter: 07 | bpp: 0.8411 | MS-SSIM: 0.9972 | PSNR: 36.9635
# iter: 08 | bpp: 0.9658 | MS-SSIM: 0.9976 | PSNR: 37.4135
# iter: 09 | bpp: 1.0910 | MS-SSIM: 0.9978 | PSNR: 37.8292
# iter: 10 | bpp: 1.2160 | MS-SSIM: 0.9981 | PSNR: 38.2541
# iter: 11 | bpp: 1.3409 | MS-SSIM: 0.9983 | PSNR: 38.6007
# iter: 12 | bpp: 1.4659 | MS-SSIM: 0.9984 | PSNR: 38.9479
# iter: 13 | bpp: 1.5909 | MS-SSIM: 0.9985 | PSNR: 39.2403
# iter: 14 | bpp: 1.7160 | MS-SSIM: 0.9986 | PSNR: 39.5328
# iter: 15 | bpp: 1.8410 | MS-SSIM: 0.9987 | PSNR: 39.7878
# iter: 16 | bpp: 1.9660 | MS-SSIM: 0.9988 | PSNR: 40.0663
# iter: 17 | bpp: 2.0114 | MS-SSIM: 0.9987 | PSNR: 39.7772
# iter: 18 | bpp: 2.0988 | MS-SSIM: 0.9986 | PSNR: 39.7696
# iter: 19 | bpp: 2.2128 | MS-SSIM: 0.9986 | PSNR: 39.7719
# iter: 20 | bpp: 2.3176 | MS-SSIM: 0.9986 | PSNR: 39.6876
# iter: 21 | bpp: 2.4272 | MS-SSIM: 0.9985 | PSNR: 39.6539
# iter: 22 | bpp: 2.5424 | MS-SSIM: 0.9985 | PSNR: 39.5854
# iter: 23 | bpp: 2.6380 | MS-SSIM: 0.9985 | PSNR: 39.3867
# iter: 24 | bpp: 2.7443 | MS-SSIM: 0.9984 | PSNR: 39.2599
# iter: 25 | bpp: 2.8561 | MS-SSIM: 0.9983 | PSNR: 39.0427
# iter: 26 | bpp: 2.9667 | MS-SSIM: 0.9982 | PSNR: 38.8830
# iter: 27 | bpp: 3.0846 | MS-SSIM: 0.9981 | PSNR: 38.7080
# iter: 28 | bpp: 3.1883 | MS-SSIM: 0.9980 | PSNR: 38.5163
# iter: 29 | bpp: 3.2897 | MS-SSIM: 0.9978 | PSNR: 38.2347
# iter: 30 | bpp: 3.3961 | MS-SSIM: 0.9977 | PSNR: 37.9403
# iter: 31 | bpp: 3.5116 | MS-SSIM: 0.9975 | PSNR: 37.6381
# iter: 32 | bpp: 3.6243 | MS-SSIM: 0.9973 | PSNR: 37.3644
# iter: 01 | bpp: 0.1051 | MS-SSIM: 0.9723 | PSNR: 30.1912
# iter: 02 | bpp: 0.2288 | MS-SSIM: 0.9857 | PSNR: 32.0234
# iter: 03 | bpp: 0.3518 | MS-SSIM: 0.9899 | PSNR: 33.0703
# iter: 04 | bpp: 0.4768 | MS-SSIM: 0.9924 | PSNR: 33.7686
# iter: 05 | bpp: 0.6018 | MS-SSIM: 0.9937 | PSNR: 34.2920
# iter: 06 | bpp: 0.7269 | MS-SSIM: 0.9948 | PSNR: 34.7664
# iter: 07 | bpp: 0.8519 | MS-SSIM: 0.9956 | PSNR: 35.2245
# iter: 08 | bpp: 0.9769 | MS-SSIM: 0.9961 | PSNR: 35.5969
# iter: 09 | bpp: 1.1020 | MS-SSIM: 0.9965 | PSNR: 35.9663
# iter: 10 | bpp: 1.2270 | MS-SSIM: 0.9969 | PSNR: 36.3192
# iter: 11 | bpp: 1.3521 | MS-SSIM: 0.9972 | PSNR: 36.6537
# iter: 12 | bpp: 1.4771 | MS-SSIM: 0.9974 | PSNR: 36.9520
# iter: 13 | bpp: 1.6021 | MS-SSIM: 0.9976 | PSNR: 37.2432
# iter: 14 | bpp: 1.7272 | MS-SSIM: 0.9977 | PSNR: 37.5123
# iter: 15 | bpp: 1.8522 | MS-SSIM: 0.9979 | PSNR: 37.7840
# iter: 16 | bpp: 1.9772 | MS-SSIM: 0.9979 | PSNR: 38.0153
# iter: 17 | bpp: 2.0374 | MS-SSIM: 0.9978 | PSNR: 37.7927
# iter: 18 | bpp: 2.1312 | MS-SSIM: 0.9977 | PSNR: 37.7831
# iter: 19 | bpp: 2.2510 | MS-SSIM: 0.9977 | PSNR: 37.8122
# iter: 20 | bpp: 2.3631 | MS-SSIM: 0.9977 | PSNR: 37.7704
# iter: 21 | bpp: 2.4743 | MS-SSIM: 0.9977 | PSNR: 37.7583
# iter: 22 | bpp: 2.5962 | MS-SSIM: 0.9977 | PSNR: 37.7343
# iter: 23 | bpp: 2.7012 | MS-SSIM: 0.9976 | PSNR: 37.5860
# iter: 24 | bpp: 2.8199 | MS-SSIM: 0.9975 | PSNR: 37.4969
# iter: 25 | bpp: 2.9330 | MS-SSIM: 0.9974 | PSNR: 37.3331
# iter: 26 | bpp: 3.0459 | MS-SSIM: 0.9974 | PSNR: 37.2265
# iter: 27 | bpp: 3.1655 | MS-SSIM: 0.9973 | PSNR: 37.1024
# iter: 28 | bpp: 3.2751 | MS-SSIM: 0.9972 | PSNR: 36.9522
# iter: 29 | bpp: 3.3789 | MS-SSIM: 0.9970 | PSNR: 36.7311
# iter: 30 | bpp: 3.4983 | MS-SSIM: 0.9968 | PSNR: 36.5074
# iter: 31 | bpp: 3.6125 | MS-SSIM: 0.9967 | PSNR: 36.2855
# iter: 32 | bpp: 3.7235 | MS-SSIM: 0.9965 | PSNR: 36.0937
# iter: 01 | bpp: 0.1304 | MS-SSIM: 0.9062 | PSNR: 29.0904
# iter: 02 | bpp: 0.2561 | MS-SSIM: 0.9360 | PSNR: 29.8963
# iter: 03 | bpp: 0.3811 | MS-SSIM: 0.9505 | PSNR: 30.4515
# iter: 04 | bpp: 0.5061 | MS-SSIM: 0.9599 | PSNR: 30.9006
# iter: 05 | bpp: 0.6311 | MS-SSIM: 0.9671 | PSNR: 31.2994
# iter: 06 | bpp: 0.7562 | MS-SSIM: 0.9725 | PSNR: 31.6981
# iter: 07 | bpp: 0.8812 | MS-SSIM: 0.9773 | PSNR: 32.0620
# iter: 08 | bpp: 1.0062 | MS-SSIM: 0.9802 | PSNR: 32.3997
# iter: 09 | bpp: 1.1313 | MS-SSIM: 0.9827 | PSNR: 32.7201
# iter: 10 | bpp: 1.2563 | MS-SSIM: 0.9850 | PSNR: 33.0653
# iter: 11 | bpp: 1.3814 | MS-SSIM: 0.9867 | PSNR: 33.3817
# iter: 12 | bpp: 1.5064 | MS-SSIM: 0.9880 | PSNR: 33.6785
# iter: 13 | bpp: 1.6314 | MS-SSIM: 0.9891 | PSNR: 33.9852
# iter: 14 | bpp: 1.7565 | MS-SSIM: 0.9901 | PSNR: 34.2644
# iter: 15 | bpp: 1.8815 | MS-SSIM: 0.9910 | PSNR: 34.5444
# iter: 16 | bpp: 2.0065 | MS-SSIM: 0.9916 | PSNR: 34.8062
# iter: 17 | bpp: 2.0770 | MS-SSIM: 0.9911 | PSNR: 34.6173
# iter: 18 | bpp: 2.1829 | MS-SSIM: 0.9908 | PSNR: 34.5896
# iter: 19 | bpp: 2.3086 | MS-SSIM: 0.9911 | PSNR: 34.6523
# iter: 20 | bpp: 2.4318 | MS-SSIM: 0.9910 | PSNR: 34.6310
# iter: 21 | bpp: 2.5516 | MS-SSIM: 0.9911 | PSNR: 34.6625
# iter: 22 | bpp: 2.6752 | MS-SSIM: 0.9913 | PSNR: 34.6811
# iter: 23 | bpp: 2.7952 | MS-SSIM: 0.9911 | PSNR: 34.6016
# iter: 24 | bpp: 2.9192 | MS-SSIM: 0.9912 | PSNR: 34.5859
# iter: 25 | bpp: 3.0409 | MS-SSIM: 0.9911 | PSNR: 34.5091
# iter: 26 | bpp: 3.1654 | MS-SSIM: 0.9910 | PSNR: 34.4419
# iter: 27 | bpp: 3.2894 | MS-SSIM: 0.9909 | PSNR: 34.3730
# iter: 28 | bpp: 3.4127 | MS-SSIM: 0.9907 | PSNR: 34.2974
# iter: 29 | bpp: 3.5344 | MS-SSIM: 0.9904 | PSNR: 34.1664
# iter: 30 | bpp: 3.6587 | MS-SSIM: 0.9902 | PSNR: 34.0458
# iter: 31 | bpp: 3.7810 | MS-SSIM: 0.9900 | PSNR: 33.9155
# iter: 32 | bpp: 3.9047 | MS-SSIM: 0.9897 | PSNR: 33.8025
# iter: 01 | bpp: 0.1009 | MS-SSIM: 0.9308 | PSNR: 29.1516
# iter: 02 | bpp: 0.2196 | MS-SSIM: 0.9657 | PSNR: 30.7568
# iter: 03 | bpp: 0.3426 | MS-SSIM: 0.9732 | PSNR: 31.3772
# iter: 04 | bpp: 0.4675 | MS-SSIM: 0.9794 | PSNR: 31.8483
# iter: 05 | bpp: 0.5919 | MS-SSIM: 0.9833 | PSNR: 32.2793
# iter: 06 | bpp: 0.7165 | MS-SSIM: 0.9858 | PSNR: 32.6779
# iter: 07 | bpp: 0.8415 | MS-SSIM: 0.9883 | PSNR: 33.0651
# iter: 08 | bpp: 0.9665 | MS-SSIM: 0.9898 | PSNR: 33.4129
# iter: 09 | bpp: 1.0913 | MS-SSIM: 0.9911 | PSNR: 33.7554
# iter: 10 | bpp: 1.2163 | MS-SSIM: 0.9922 | PSNR: 34.0968
# iter: 11 | bpp: 1.3413 | MS-SSIM: 0.9931 | PSNR: 34.4210
# iter: 12 | bpp: 1.4664 | MS-SSIM: 0.9939 | PSNR: 34.7218
# iter: 13 | bpp: 1.5914 | MS-SSIM: 0.9944 | PSNR: 35.0535
# iter: 14 | bpp: 1.7165 | MS-SSIM: 0.9949 | PSNR: 35.3546
# iter: 15 | bpp: 1.8415 | MS-SSIM: 0.9954 | PSNR: 35.6608
# iter: 16 | bpp: 1.9665 | MS-SSIM: 0.9957 | PSNR: 35.9384
# iter: 17 | bpp: 2.0350 | MS-SSIM: 0.9954 | PSNR: 35.6627
# iter: 18 | bpp: 2.1313 | MS-SSIM: 0.9952 | PSNR: 35.6502
# iter: 19 | bpp: 2.2478 | MS-SSIM: 0.9953 | PSNR: 35.6636
# iter: 20 | bpp: 2.3641 | MS-SSIM: 0.9952 | PSNR: 35.6298
# iter: 21 | bpp: 2.4790 | MS-SSIM: 0.9953 | PSNR: 35.6626
# iter: 22 | bpp: 2.5983 | MS-SSIM: 0.9954 | PSNR: 35.6707
# iter: 23 | bpp: 2.7112 | MS-SSIM: 0.9953 | PSNR: 35.5683
# iter: 24 | bpp: 2.8291 | MS-SSIM: 0.9953 | PSNR: 35.5352
# iter: 25 | bpp: 2.9473 | MS-SSIM: 0.9952 | PSNR: 35.4054
# iter: 26 | bpp: 3.0672 | MS-SSIM: 0.9951 | PSNR: 35.3235
# iter: 27 | bpp: 3.1888 | MS-SSIM: 0.9950 | PSNR: 35.2528
# iter: 28 | bpp: 3.3046 | MS-SSIM: 0.9949 | PSNR: 35.1813
# iter: 29 | bpp: 3.4191 | MS-SSIM: 0.9947 | PSNR: 35.0537
# iter: 30 | bpp: 3.5404 | MS-SSIM: 0.9946 | PSNR: 34.9151
# iter: 31 | bpp: 3.6584 | MS-SSIM: 0.9944 | PSNR: 34.7610
# iter: 32 | bpp: 3.7777 | MS-SSIM: 0.9943 | PSNR: 34.6382
# iter: 01 | bpp: 0.1156 | MS-SSIM: 0.9625 | PSNR: 30.2160
# iter: 02 | bpp: 0.2371 | MS-SSIM: 0.9855 | PSNR: 32.4837
# iter: 03 | bpp: 0.3594 | MS-SSIM: 0.9910 | PSNR: 33.8559
# iter: 04 | bpp: 0.4839 | MS-SSIM: 0.9936 | PSNR: 34.7701
# iter: 05 | bpp: 0.6085 | MS-SSIM: 0.9950 | PSNR: 35.4878
# iter: 06 | bpp: 0.7334 | MS-SSIM: 0.9960 | PSNR: 36.0947
# iter: 07 | bpp: 0.8584 | MS-SSIM: 0.9968 | PSNR: 36.6910
# iter: 08 | bpp: 0.9834 | MS-SSIM: 0.9972 | PSNR: 37.1459
# iter: 09 | bpp: 1.1085 | MS-SSIM: 0.9976 | PSNR: 37.5863
# iter: 10 | bpp: 1.2335 | MS-SSIM: 0.9979 | PSNR: 37.9878
# iter: 11 | bpp: 1.3586 | MS-SSIM: 0.9981 | PSNR: 38.3869
# iter: 12 | bpp: 1.4836 | MS-SSIM: 0.9983 | PSNR: 38.7159
# iter: 13 | bpp: 1.6086 | MS-SSIM: 0.9984 | PSNR: 39.0592
# iter: 14 | bpp: 1.7337 | MS-SSIM: 0.9985 | PSNR: 39.3563
# iter: 15 | bpp: 1.8587 | MS-SSIM: 0.9986 | PSNR: 39.6146
# iter: 16 | bpp: 1.9837 | MS-SSIM: 0.9987 | PSNR: 39.8371
# iter: 17 | bpp: 2.0365 | MS-SSIM: 0.9986 | PSNR: 39.6396
# iter: 18 | bpp: 2.1258 | MS-SSIM: 0.9985 | PSNR: 39.6454
# iter: 19 | bpp: 2.2417 | MS-SSIM: 0.9985 | PSNR: 39.7079
# iter: 20 | bpp: 2.3498 | MS-SSIM: 0.9985 | PSNR: 39.6570
# iter: 21 | bpp: 2.4609 | MS-SSIM: 0.9985 | PSNR: 39.6464
# iter: 22 | bpp: 2.5792 | MS-SSIM: 0.9985 | PSNR: 39.6045
# iter: 23 | bpp: 2.6767 | MS-SSIM: 0.9984 | PSNR: 39.4209
# iter: 24 | bpp: 2.7874 | MS-SSIM: 0.9983 | PSNR: 39.2650
# iter: 25 | bpp: 2.9018 | MS-SSIM: 0.9983 | PSNR: 39.0649
# iter: 26 | bpp: 3.0143 | MS-SSIM: 0.9982 | PSNR: 38.9099
# iter: 27 | bpp: 3.1339 | MS-SSIM: 0.9981 | PSNR: 38.7297
# iter: 28 | bpp: 3.2391 | MS-SSIM: 0.9980 | PSNR: 38.5189
# iter: 29 | bpp: 3.3397 | MS-SSIM: 0.9978 | PSNR: 38.2106
# iter: 30 | bpp: 3.4506 | MS-SSIM: 0.9977 | PSNR: 37.8800
# iter: 31 | bpp: 3.5670 | MS-SSIM: 0.9975 | PSNR: 37.5521
# iter: 32 | bpp: 3.6799 | MS-SSIM: 0.9973 | PSNR: 37.2592
# iter: 01 | bpp: 0.1285 | MS-SSIM: 0.8932 | PSNR: 28.9071
# iter: 02 | bpp: 0.2546 | MS-SSIM: 0.9260 | PSNR: 29.6415
# iter: 03 | bpp: 0.3799 | MS-SSIM: 0.9409 | PSNR: 30.0952
# iter: 04 | bpp: 0.5049 | MS-SSIM: 0.9504 | PSNR: 30.4958
# iter: 05 | bpp: 0.6299 | MS-SSIM: 0.9581 | PSNR: 30.8855
# iter: 06 | bpp: 0.7550 | MS-SSIM: 0.9638 | PSNR: 31.2622
# iter: 07 | bpp: 0.8800 | MS-SSIM: 0.9688 | PSNR: 31.6142
# iter: 08 | bpp: 1.0050 | MS-SSIM: 0.9718 | PSNR: 31.9444
# iter: 09 | bpp: 1.1301 | MS-SSIM: 0.9751 | PSNR: 32.2485
# iter: 10 | bpp: 1.2551 | MS-SSIM: 0.9776 | PSNR: 32.5598
# iter: 11 | bpp: 1.3802 | MS-SSIM: 0.9797 | PSNR: 32.8595
# iter: 12 | bpp: 1.5052 | MS-SSIM: 0.9817 | PSNR: 33.1416
# iter: 13 | bpp: 1.6302 | MS-SSIM: 0.9832 | PSNR: 33.4208
# iter: 14 | bpp: 1.7553 | MS-SSIM: 0.9845 | PSNR: 33.6945
# iter: 15 | bpp: 1.8803 | MS-SSIM: 0.9858 | PSNR: 33.9567
# iter: 16 | bpp: 2.0053 | MS-SSIM: 0.9866 | PSNR: 34.1904
# iter: 17 | bpp: 2.0854 | MS-SSIM: 0.9859 | PSNR: 33.9989
# iter: 18 | bpp: 2.1936 | MS-SSIM: 0.9857 | PSNR: 33.9998
# iter: 19 | bpp: 2.3199 | MS-SSIM: 0.9861 | PSNR: 34.0592
# iter: 20 | bpp: 2.4431 | MS-SSIM: 0.9861 | PSNR: 34.0588
# iter: 21 | bpp: 2.5625 | MS-SSIM: 0.9863 | PSNR: 34.0902
# iter: 22 | bpp: 2.6874 | MS-SSIM: 0.9866 | PSNR: 34.1168
# iter: 23 | bpp: 2.8100 | MS-SSIM: 0.9865 | PSNR: 34.0547
# iter: 24 | bpp: 2.9342 | MS-SSIM: 0.9866 | PSNR: 34.0384
# iter: 25 | bpp: 3.0567 | MS-SSIM: 0.9865 | PSNR: 33.9509
# iter: 26 | bpp: 3.1815 | MS-SSIM: 0.9864 | PSNR: 33.8997
# iter: 27 | bpp: 3.3058 | MS-SSIM: 0.9863 | PSNR: 33.8462
# iter: 28 | bpp: 3.4305 | MS-SSIM: 0.9861 | PSNR: 33.7854
# iter: 29 | bpp: 3.5532 | MS-SSIM: 0.9857 | PSNR: 33.6732
# iter: 30 | bpp: 3.6780 | MS-SSIM: 0.9856 | PSNR: 33.5653
# iter: 31 | bpp: 3.8016 | MS-SSIM: 0.9853 | PSNR: 33.4413
# iter: 32 | bpp: 3.9246 | MS-SSIM: 0.9850 | PSNR: 33.3415
# iter: 01 | bpp: 0.0928 | MS-SSIM: 0.9343 | PSNR: 30.7217
# iter: 02 | bpp: 0.2105 | MS-SSIM: 0.9691 | PSNR: 32.9905
# iter: 03 | bpp: 0.3322 | MS-SSIM: 0.9774 | PSNR: 34.1686
# iter: 04 | bpp: 0.4570 | MS-SSIM: 0.9825 | PSNR: 34.8995
# iter: 05 | bpp: 0.5818 | MS-SSIM: 0.9852 | PSNR: 35.4888
# iter: 06 | bpp: 0.7068 | MS-SSIM: 0.9873 | PSNR: 35.9830
# iter: 07 | bpp: 0.8318 | MS-SSIM: 0.9892 | PSNR: 36.5104
# iter: 08 | bpp: 0.9568 | MS-SSIM: 0.9902 | PSNR: 36.9232
# iter: 09 | bpp: 1.0819 | MS-SSIM: 0.9913 | PSNR: 37.3220
# iter: 10 | bpp: 1.2069 | MS-SSIM: 0.9922 | PSNR: 37.6991
# iter: 11 | bpp: 1.3319 | MS-SSIM: 0.9928 | PSNR: 38.0367
# iter: 12 | bpp: 1.4570 | MS-SSIM: 0.9935 | PSNR: 38.3538
# iter: 13 | bpp: 1.5820 | MS-SSIM: 0.9939 | PSNR: 38.6589
# iter: 14 | bpp: 1.7071 | MS-SSIM: 0.9942 | PSNR: 38.9332
# iter: 15 | bpp: 1.8321 | MS-SSIM: 0.9946 | PSNR: 39.1966
# iter: 16 | bpp: 1.9571 | MS-SSIM: 0.9948 | PSNR: 39.4160
# iter: 17 | bpp: 2.0143 | MS-SSIM: 0.9945 | PSNR: 39.1858
# iter: 18 | bpp: 2.1036 | MS-SSIM: 0.9943 | PSNR: 39.1953
# iter: 19 | bpp: 2.2202 | MS-SSIM: 0.9944 | PSNR: 39.2220
# iter: 20 | bpp: 2.3264 | MS-SSIM: 0.9943 | PSNR: 39.1802
# iter: 21 | bpp: 2.4360 | MS-SSIM: 0.9944 | PSNR: 39.1660
# iter: 22 | bpp: 2.5575 | MS-SSIM: 0.9944 | PSNR: 39.1336
# iter: 23 | bpp: 2.6585 | MS-SSIM: 0.9942 | PSNR: 38.9796
# iter: 24 | bpp: 2.7735 | MS-SSIM: 0.9941 | PSNR: 38.8516
# iter: 25 | bpp: 2.8874 | MS-SSIM: 0.9938 | PSNR: 38.6318
# iter: 26 | bpp: 2.9963 | MS-SSIM: 0.9937 | PSNR: 38.5002
# iter: 27 | bpp: 3.1139 | MS-SSIM: 0.9935 | PSNR: 38.3640
# iter: 28 | bpp: 3.2206 | MS-SSIM: 0.9931 | PSNR: 38.1897
# iter: 29 | bpp: 3.3172 | MS-SSIM: 0.9927 | PSNR: 37.9198
# iter: 30 | bpp: 3.4361 | MS-SSIM: 0.9923 | PSNR: 37.6220
# iter: 31 | bpp: 3.5496 | MS-SSIM: 0.9919 | PSNR: 37.3076
# iter: 32 | bpp: 3.6518 | MS-SSIM: 0.9915 | PSNR: 37.0606
# iter: 01 | bpp: 0.1051 | MS-SSIM: 0.9302 | PSNR: 30.1684
# iter: 02 | bpp: 0.2281 | MS-SSIM: 0.9685 | PSNR: 32.7448
# iter: 03 | bpp: 0.3522 | MS-SSIM: 0.9775 | PSNR: 33.9512
# iter: 04 | bpp: 0.4772 | MS-SSIM: 0.9823 | PSNR: 34.7992
# iter: 05 | bpp: 0.6022 | MS-SSIM: 0.9854 | PSNR: 35.4675
# iter: 06 | bpp: 0.7273 | MS-SSIM: 0.9879 | PSNR: 36.0317
# iter: 07 | bpp: 0.8523 | MS-SSIM: 0.9897 | PSNR: 36.5898
# iter: 08 | bpp: 0.9773 | MS-SSIM: 0.9909 | PSNR: 37.0321
# iter: 09 | bpp: 1.1024 | MS-SSIM: 0.9920 | PSNR: 37.4448
# iter: 10 | bpp: 1.2274 | MS-SSIM: 0.9929 | PSNR: 37.8357
# iter: 11 | bpp: 1.3525 | MS-SSIM: 0.9935 | PSNR: 38.1845
# iter: 12 | bpp: 1.4775 | MS-SSIM: 0.9941 | PSNR: 38.4961
# iter: 13 | bpp: 1.6025 | MS-SSIM: 0.9945 | PSNR: 38.7963
# iter: 14 | bpp: 1.7276 | MS-SSIM: 0.9949 | PSNR: 39.0778
# iter: 15 | bpp: 1.8526 | MS-SSIM: 0.9952 | PSNR: 39.3430
# iter: 16 | bpp: 1.9776 | MS-SSIM: 0.9955 | PSNR: 39.5668
# iter: 17 | bpp: 2.0340 | MS-SSIM: 0.9951 | PSNR: 39.3283
# iter: 18 | bpp: 2.1225 | MS-SSIM: 0.9949 | PSNR: 39.3301
# iter: 19 | bpp: 2.2408 | MS-SSIM: 0.9950 | PSNR: 39.3611
# iter: 20 | bpp: 2.3481 | MS-SSIM: 0.9950 | PSNR: 39.3114
# iter: 21 | bpp: 2.4595 | MS-SSIM: 0.9950 | PSNR: 39.3053
# iter: 22 | bpp: 2.5815 | MS-SSIM: 0.9950 | PSNR: 39.2510
# iter: 23 | bpp: 2.6840 | MS-SSIM: 0.9948 | PSNR: 39.0858
# iter: 24 | bpp: 2.7994 | MS-SSIM: 0.9947 | PSNR: 38.9540
# iter: 25 | bpp: 2.9139 | MS-SSIM: 0.9945 | PSNR: 38.7369
# iter: 26 | bpp: 3.0225 | MS-SSIM: 0.9944 | PSNR: 38.6047
# iter: 27 | bpp: 3.1399 | MS-SSIM: 0.9943 | PSNR: 38.4664
# iter: 28 | bpp: 3.2437 | MS-SSIM: 0.9940 | PSNR: 38.2814
# iter: 29 | bpp: 3.3421 | MS-SSIM: 0.9936 | PSNR: 37.9944
# iter: 30 | bpp: 3.4590 | MS-SSIM: 0.9933 | PSNR: 37.6891
# iter: 31 | bpp: 3.5735 | MS-SSIM: 0.9930 | PSNR: 37.3828
# iter: 32 | bpp: 3.6805 | MS-SSIM: 0.9926 | PSNR: 37.1377
# iter: 01 | bpp: 0.1021 | MS-SSIM: 0.8815 | PSNR: 29.2581
# iter: 02 | bpp: 0.2183 | MS-SSIM: 0.9590 | PSNR: 31.2901
# iter: 03 | bpp: 0.3416 | MS-SSIM: 0.9695 | PSNR: 32.0401
# iter: 04 | bpp: 0.4666 | MS-SSIM: 0.9759 | PSNR: 32.6017
# iter: 05 | bpp: 0.5910 | MS-SSIM: 0.9804 | PSNR: 33.1114
# iter: 06 | bpp: 0.7157 | MS-SSIM: 0.9832 | PSNR: 33.5642
# iter: 07 | bpp: 0.8407 | MS-SSIM: 0.9859 | PSNR: 34.0016
# iter: 08 | bpp: 0.9657 | MS-SSIM: 0.9875 | PSNR: 34.3644
# iter: 09 | bpp: 1.0908 | MS-SSIM: 0.9892 | PSNR: 34.7741
# iter: 10 | bpp: 1.2158 | MS-SSIM: 0.9905 | PSNR: 35.1273
# iter: 11 | bpp: 1.3408 | MS-SSIM: 0.9915 | PSNR: 35.4652
# iter: 12 | bpp: 1.4659 | MS-SSIM: 0.9924 | PSNR: 35.7805
# iter: 13 | bpp: 1.5909 | MS-SSIM: 0.9930 | PSNR: 36.0765
# iter: 14 | bpp: 1.7160 | MS-SSIM: 0.9935 | PSNR: 36.3833
# iter: 15 | bpp: 1.8410 | MS-SSIM: 0.9941 | PSNR: 36.6727
# iter: 16 | bpp: 1.9660 | MS-SSIM: 0.9944 | PSNR: 36.9292
# iter: 17 | bpp: 2.0331 | MS-SSIM: 0.9940 | PSNR: 36.6983
# iter: 18 | bpp: 2.1295 | MS-SSIM: 0.9938 | PSNR: 36.6862
# iter: 19 | bpp: 2.2507 | MS-SSIM: 0.9939 | PSNR: 36.7139
# iter: 20 | bpp: 2.3650 | MS-SSIM: 0.9937 | PSNR: 36.6778
# iter: 21 | bpp: 2.4788 | MS-SSIM: 0.9939 | PSNR: 36.7021
# iter: 22 | bpp: 2.6006 | MS-SSIM: 0.9939 | PSNR: 36.6938
# iter: 23 | bpp: 2.7112 | MS-SSIM: 0.9937 | PSNR: 36.5754
# iter: 24 | bpp: 2.8303 | MS-SSIM: 0.9936 | PSNR: 36.5147
# iter: 25 | bpp: 2.9474 | MS-SSIM: 0.9934 | PSNR: 36.3755
# iter: 26 | bpp: 3.0652 | MS-SSIM: 0.9933 | PSNR: 36.2823
# iter: 27 | bpp: 3.1859 | MS-SSIM: 0.9931 | PSNR: 36.1817
# iter: 28 | bpp: 3.3002 | MS-SSIM: 0.9929 | PSNR: 36.0666
# iter: 29 | bpp: 3.4109 | MS-SSIM: 0.9925 | PSNR: 35.8880
# iter: 30 | bpp: 3.5317 | MS-SSIM: 0.9923 | PSNR: 35.6992
# iter: 31 | bpp: 3.6469 | MS-SSIM: 0.9919 | PSNR: 35.5032
# iter: 32 | bpp: 3.7629 | MS-SSIM: 0.9916 | PSNR: 35.3465
# iter: 01 | bpp: 0.0849 | MS-SSIM: 0.9631 | PSNR: 30.3450
# iter: 02 | bpp: 0.2008 | MS-SSIM: 0.9826 | PSNR: 32.6747
# iter: 03 | bpp: 0.3232 | MS-SSIM: 0.9883 | PSNR: 33.8283
# iter: 04 | bpp: 0.4483 | MS-SSIM: 0.9913 | PSNR: 34.6917
# iter: 05 | bpp: 0.5730 | MS-SSIM: 0.9930 | PSNR: 35.3594
# iter: 06 | bpp: 0.6979 | MS-SSIM: 0.9941 | PSNR: 35.9698
# iter: 07 | bpp: 0.8229 | MS-SSIM: 0.9952 | PSNR: 36.5619
# iter: 08 | bpp: 0.9479 | MS-SSIM: 0.9958 | PSNR: 37.0135
# iter: 09 | bpp: 1.0730 | MS-SSIM: 0.9963 | PSNR: 37.4768
# iter: 10 | bpp: 1.1980 | MS-SSIM: 0.9968 | PSNR: 37.9115
# iter: 11 | bpp: 1.3230 | MS-SSIM: 0.9971 | PSNR: 38.3104
# iter: 12 | bpp: 1.4481 | MS-SSIM: 0.9974 | PSNR: 38.6554
# iter: 13 | bpp: 1.5731 | MS-SSIM: 0.9976 | PSNR: 38.9940
# iter: 14 | bpp: 1.6982 | MS-SSIM: 0.9978 | PSNR: 39.2945
# iter: 15 | bpp: 1.8232 | MS-SSIM: 0.9980 | PSNR: 39.5985
# iter: 16 | bpp: 1.9482 | MS-SSIM: 0.9981 | PSNR: 39.8604
# iter: 17 | bpp: 1.9983 | MS-SSIM: 0.9979 | PSNR: 39.5587
# iter: 18 | bpp: 2.0860 | MS-SSIM: 0.9979 | PSNR: 39.5793
# iter: 19 | bpp: 2.2024 | MS-SSIM: 0.9979 | PSNR: 39.5739
# iter: 20 | bpp: 2.3061 | MS-SSIM: 0.9978 | PSNR: 39.5078
# iter: 21 | bpp: 2.4132 | MS-SSIM: 0.9978 | PSNR: 39.4984
# iter: 22 | bpp: 2.5325 | MS-SSIM: 0.9979 | PSNR: 39.4535
# iter: 23 | bpp: 2.6345 | MS-SSIM: 0.9978 | PSNR: 39.2658
# iter: 24 | bpp: 2.7452 | MS-SSIM: 0.9977 | PSNR: 39.1270
# iter: 25 | bpp: 2.8607 | MS-SSIM: 0.9976 | PSNR: 38.8674
# iter: 26 | bpp: 2.9695 | MS-SSIM: 0.9976 | PSNR: 38.7320
# iter: 27 | bpp: 3.0845 | MS-SSIM: 0.9975 | PSNR: 38.5901
# iter: 28 | bpp: 3.1877 | MS-SSIM: 0.9974 | PSNR: 38.4174
# iter: 29 | bpp: 3.2866 | MS-SSIM: 0.9972 | PSNR: 38.1313
# iter: 30 | bpp: 3.4021 | MS-SSIM: 0.9971 | PSNR: 37.8137
# iter: 31 | bpp: 3.5147 | MS-SSIM: 0.9969 | PSNR: 37.4949
# iter: 32 | bpp: 3.6188 | MS-SSIM: 0.9968 | PSNR: 37.2501
# iter: 01 | bpp: 0.1233 | MS-SSIM: 0.9296 | PSNR: 28.8640
# iter: 02 | bpp: 0.2496 | MS-SSIM: 0.9505 | PSNR: 29.3850
# iter: 03 | bpp: 0.3751 | MS-SSIM: 0.9583 | PSNR: 29.6580
# iter: 04 | bpp: 0.5001 | MS-SSIM: 0.9645 | PSNR: 29.8855
# iter: 05 | bpp: 0.6251 | MS-SSIM: 0.9695 | PSNR: 30.1124
# iter: 06 | bpp: 0.7502 | MS-SSIM: 0.9732 | PSNR: 30.3366
# iter: 07 | bpp: 0.8752 | MS-SSIM: 0.9769 | PSNR: 30.5595
# iter: 08 | bpp: 1.0002 | MS-SSIM: 0.9798 | PSNR: 30.7754
# iter: 09 | bpp: 1.1253 | MS-SSIM: 0.9821 | PSNR: 30.9805
# iter: 10 | bpp: 1.2503 | MS-SSIM: 0.9842 | PSNR: 31.2037
# iter: 11 | bpp: 1.3754 | MS-SSIM: 0.9857 | PSNR: 31.4246
# iter: 12 | bpp: 1.5004 | MS-SSIM: 0.9870 | PSNR: 31.6295
# iter: 13 | bpp: 1.6254 | MS-SSIM: 0.9881 | PSNR: 31.8550
# iter: 14 | bpp: 1.7505 | MS-SSIM: 0.9891 | PSNR: 32.0896
# iter: 15 | bpp: 1.8755 | MS-SSIM: 0.9901 | PSNR: 32.3129
# iter: 16 | bpp: 2.0005 | MS-SSIM: 0.9908 | PSNR: 32.5433
# iter: 17 | bpp: 2.0848 | MS-SSIM: 0.9903 | PSNR: 32.3608
# iter: 18 | bpp: 2.1869 | MS-SSIM: 0.9900 | PSNR: 32.3362
# iter: 19 | bpp: 2.3099 | MS-SSIM: 0.9902 | PSNR: 32.3602
# iter: 20 | bpp: 2.4329 | MS-SSIM: 0.9900 | PSNR: 32.3378
# iter: 21 | bpp: 2.5540 | MS-SSIM: 0.9901 | PSNR: 32.3680
# iter: 22 | bpp: 2.6769 | MS-SSIM: 0.9903 | PSNR: 32.4002
# iter: 23 | bpp: 2.7996 | MS-SSIM: 0.9902 | PSNR: 32.3513
# iter: 24 | bpp: 2.9245 | MS-SSIM: 0.9902 | PSNR: 32.3533
# iter: 25 | bpp: 3.0473 | MS-SSIM: 0.9902 | PSNR: 32.3022
# iter: 26 | bpp: 3.1723 | MS-SSIM: 0.9901 | PSNR: 32.2610
# iter: 27 | bpp: 3.2970 | MS-SSIM: 0.9900 | PSNR: 32.2318
# iter: 28 | bpp: 3.4220 | MS-SSIM: 0.9900 | PSNR: 32.1965
# iter: 29 | bpp: 3.5470 | MS-SSIM: 0.9898 | PSNR: 32.1488
# iter: 30 | bpp: 3.6719 | MS-SSIM: 0.9897 | PSNR: 32.0940
# iter: 31 | bpp: 3.7962 | MS-SSIM: 0.9895 | PSNR: 32.0222
# iter: 32 | bpp: 3.9209 | MS-SSIM: 0.9894 | PSNR: 31.9652
# iter: 01 | bpp: 0.1220 | MS-SSIM: 0.9387 | PSNR: 29.4778
# iter: 02 | bpp: 0.2474 | MS-SSIM: 0.9603 | PSNR: 30.6045
# iter: 03 | bpp: 0.3722 | MS-SSIM: 0.9692 | PSNR: 31.2711
# iter: 04 | bpp: 0.4972 | MS-SSIM: 0.9751 | PSNR: 31.7570
# iter: 05 | bpp: 0.6222 | MS-SSIM: 0.9792 | PSNR: 32.2023
# iter: 06 | bpp: 0.7473 | MS-SSIM: 0.9823 | PSNR: 32.6073
# iter: 07 | bpp: 0.8723 | MS-SSIM: 0.9853 | PSNR: 33.0185
# iter: 08 | bpp: 0.9973 | MS-SSIM: 0.9872 | PSNR: 33.3889
# iter: 09 | bpp: 1.1224 | MS-SSIM: 0.9889 | PSNR: 33.7566
# iter: 10 | bpp: 1.2473 | MS-SSIM: 0.9903 | PSNR: 34.1145
# iter: 11 | bpp: 1.3725 | MS-SSIM: 0.9913 | PSNR: 34.4448
# iter: 12 | bpp: 1.4975 | MS-SSIM: 0.9923 | PSNR: 34.7510
# iter: 13 | bpp: 1.6225 | MS-SSIM: 0.9930 | PSNR: 35.0604
# iter: 14 | bpp: 1.7476 | MS-SSIM: 0.9936 | PSNR: 35.3551
# iter: 15 | bpp: 1.8726 | MS-SSIM: 0.9942 | PSNR: 35.6453
# iter: 16 | bpp: 1.9976 | MS-SSIM: 0.9946 | PSNR: 35.9046
# iter: 17 | bpp: 2.0671 | MS-SSIM: 0.9942 | PSNR: 35.6730
# iter: 18 | bpp: 2.1653 | MS-SSIM: 0.9939 | PSNR: 35.6726
# iter: 19 | bpp: 2.2893 | MS-SSIM: 0.9941 | PSNR: 35.7077
# iter: 20 | bpp: 2.4082 | MS-SSIM: 0.9940 | PSNR: 35.6791
# iter: 21 | bpp: 2.5225 | MS-SSIM: 0.9940 | PSNR: 35.7006
# iter: 22 | bpp: 2.6468 | MS-SSIM: 0.9941 | PSNR: 35.7027
# iter: 23 | bpp: 2.7653 | MS-SSIM: 0.9940 | PSNR: 35.6012
# iter: 24 | bpp: 2.8873 | MS-SSIM: 0.9940 | PSNR: 35.5610
# iter: 25 | bpp: 3.0071 | MS-SSIM: 0.9939 | PSNR: 35.4506
# iter: 26 | bpp: 3.1299 | MS-SSIM: 0.9938 | PSNR: 35.3773
# iter: 27 | bpp: 3.2525 | MS-SSIM: 0.9937 | PSNR: 35.2943
# iter: 28 | bpp: 3.3718 | MS-SSIM: 0.9935 | PSNR: 35.2058
# iter: 29 | bpp: 3.4909 | MS-SSIM: 0.9932 | PSNR: 35.0527
# iter: 30 | bpp: 3.6144 | MS-SSIM: 0.9931 | PSNR: 34.9113
# iter: 31 | bpp: 3.7340 | MS-SSIM: 0.9929 | PSNR: 34.7676
# iter: 32 | bpp: 3.8548 | MS-SSIM: 0.9927 | PSNR: 34.6466
# iter: 01 | bpp: 0.1045 | MS-SSIM: 0.9302 | PSNR: 29.8179
# iter: 02 | bpp: 0.2224 | MS-SSIM: 0.9656 | PSNR: 32.0977
# iter: 03 | bpp: 0.3442 | MS-SSIM: 0.9799 | PSNR: 33.4103
# iter: 04 | bpp: 0.4683 | MS-SSIM: 0.9844 | PSNR: 34.0868
# iter: 05 | bpp: 0.5928 | MS-SSIM: 0.9867 | PSNR: 34.5247
# iter: 06 | bpp: 0.7178 | MS-SSIM: 0.9885 | PSNR: 34.9331
# iter: 07 | bpp: 0.8428 | MS-SSIM: 0.9901 | PSNR: 35.3157
# iter: 08 | bpp: 0.9678 | MS-SSIM: 0.9912 | PSNR: 35.6776
# iter: 09 | bpp: 1.0929 | MS-SSIM: 0.9921 | PSNR: 35.9624
# iter: 10 | bpp: 1.2179 | MS-SSIM: 0.9930 | PSNR: 36.2895
# iter: 11 | bpp: 1.3430 | MS-SSIM: 0.9936 | PSNR: 36.5997
# iter: 12 | bpp: 1.4680 | MS-SSIM: 0.9942 | PSNR: 36.8473
# iter: 13 | bpp: 1.5930 | MS-SSIM: 0.9946 | PSNR: 37.1097
# iter: 14 | bpp: 1.7181 | MS-SSIM: 0.9949 | PSNR: 37.3607
# iter: 15 | bpp: 1.8431 | MS-SSIM: 0.9953 | PSNR: 37.5839
# iter: 16 | bpp: 1.9681 | MS-SSIM: 0.9955 | PSNR: 37.7937
# iter: 17 | bpp: 2.0254 | MS-SSIM: 0.9952 | PSNR: 37.6109
# iter: 18 | bpp: 2.1242 | MS-SSIM: 0.9951 | PSNR: 37.5899
# iter: 19 | bpp: 2.2419 | MS-SSIM: 0.9951 | PSNR: 37.6485
# iter: 20 | bpp: 2.3537 | MS-SSIM: 0.9951 | PSNR: 37.6111
# iter: 21 | bpp: 2.4672 | MS-SSIM: 0.9951 | PSNR: 37.5894
# iter: 22 | bpp: 2.5886 | MS-SSIM: 0.9951 | PSNR: 37.5520
# iter: 23 | bpp: 2.6961 | MS-SSIM: 0.9949 | PSNR: 37.4206
# iter: 24 | bpp: 2.8122 | MS-SSIM: 0.9948 | PSNR: 37.3368
# iter: 25 | bpp: 2.9290 | MS-SSIM: 0.9947 | PSNR: 37.2146
# iter: 26 | bpp: 3.0472 | MS-SSIM: 0.9945 | PSNR: 37.1130
# iter: 27 | bpp: 3.1696 | MS-SSIM: 0.9944 | PSNR: 37.0008
# iter: 28 | bpp: 3.2853 | MS-SSIM: 0.9941 | PSNR: 36.8480
# iter: 29 | bpp: 3.3963 | MS-SSIM: 0.9938 | PSNR: 36.6309
# iter: 30 | bpp: 3.5162 | MS-SSIM: 0.9935 | PSNR: 36.4206
# iter: 31 | bpp: 3.6336 | MS-SSIM: 0.9931 | PSNR: 36.2064
# iter: 32 | bpp: 3.7513 | MS-SSIM: 0.9928 | PSNR: 36.0016
# iter: 01 | bpp: 0.0950 | MS-SSIM: 0.9375 | PSNR: 30.1677
# iter: 02 | bpp: 0.2155 | MS-SSIM: 0.9679 | PSNR: 32.0906
# iter: 03 | bpp: 0.3389 | MS-SSIM: 0.9757 | PSNR: 32.8779
# iter: 04 | bpp: 0.4639 | MS-SSIM: 0.9816 | PSNR: 33.5374
# iter: 05 | bpp: 0.5889 | MS-SSIM: 0.9850 | PSNR: 34.0948
# iter: 06 | bpp: 0.7137 | MS-SSIM: 0.9875 | PSNR: 34.6512
# iter: 07 | bpp: 0.8387 | MS-SSIM: 0.9896 | PSNR: 35.1533
# iter: 08 | bpp: 0.9637 | MS-SSIM: 0.9909 | PSNR: 35.5987
# iter: 09 | bpp: 1.0888 | MS-SSIM: 0.9921 | PSNR: 36.0313
# iter: 10 | bpp: 1.2138 | MS-SSIM: 0.9931 | PSNR: 36.4594
# iter: 11 | bpp: 1.3388 | MS-SSIM: 0.9938 | PSNR: 36.8389
# iter: 12 | bpp: 1.4639 | MS-SSIM: 0.9945 | PSNR: 37.1923
# iter: 13 | bpp: 1.5889 | MS-SSIM: 0.9950 | PSNR: 37.5716
# iter: 14 | bpp: 1.7141 | MS-SSIM: 0.9954 | PSNR: 37.9129
# iter: 15 | bpp: 1.8391 | MS-SSIM: 0.9958 | PSNR: 38.2552
# iter: 16 | bpp: 1.9641 | MS-SSIM: 0.9961 | PSNR: 38.5667
# iter: 17 | bpp: 2.0195 | MS-SSIM: 0.9957 | PSNR: 38.2424
# iter: 18 | bpp: 2.1057 | MS-SSIM: 0.9955 | PSNR: 38.2294
# iter: 19 | bpp: 2.2218 | MS-SSIM: 0.9956 | PSNR: 38.2272
# iter: 20 | bpp: 2.3288 | MS-SSIM: 0.9955 | PSNR: 38.1688
# iter: 21 | bpp: 2.4386 | MS-SSIM: 0.9955 | PSNR: 38.1676
# iter: 22 | bpp: 2.5583 | MS-SSIM: 0.9956 | PSNR: 38.1480
# iter: 23 | bpp: 2.6604 | MS-SSIM: 0.9954 | PSNR: 38.0091
# iter: 24 | bpp: 2.7739 | MS-SSIM: 0.9954 | PSNR: 37.9122
# iter: 25 | bpp: 2.8871 | MS-SSIM: 0.9952 | PSNR: 37.7169
# iter: 26 | bpp: 2.9975 | MS-SSIM: 0.9951 | PSNR: 37.5951
# iter: 27 | bpp: 3.1129 | MS-SSIM: 0.9950 | PSNR: 37.4771
# iter: 28 | bpp: 3.2180 | MS-SSIM: 0.9948 | PSNR: 37.3444
# iter: 29 | bpp: 3.3209 | MS-SSIM: 0.9945 | PSNR: 37.1348
# iter: 30 | bpp: 3.4326 | MS-SSIM: 0.9944 | PSNR: 36.9083
# iter: 31 | bpp: 3.5473 | MS-SSIM: 0.9941 | PSNR: 36.6629
# iter: 32 | bpp: 3.6582 | MS-SSIM: 0.9939 | PSNR: 36.4687
# iter: 01 | bpp: 0.1147 | MS-SSIM: 0.9485 | PSNR: 30.5023
# iter: 02 | bpp: 0.2378 | MS-SSIM: 0.9719 | PSNR: 32.6540
# iter: 03 | bpp: 0.3613 | MS-SSIM: 0.9807 | PSNR: 33.8737
# iter: 04 | bpp: 0.4863 | MS-SSIM: 0.9845 | PSNR: 34.6560
# iter: 05 | bpp: 0.6112 | MS-SSIM: 0.9873 | PSNR: 35.2796
# iter: 06 | bpp: 0.7364 | MS-SSIM: 0.9891 | PSNR: 35.7874
# iter: 07 | bpp: 0.8614 | MS-SSIM: 0.9908 | PSNR: 36.2752
# iter: 08 | bpp: 0.9864 | MS-SSIM: 0.9918 | PSNR: 36.6885
# iter: 09 | bpp: 1.1115 | MS-SSIM: 0.9927 | PSNR: 37.0689
# iter: 10 | bpp: 1.2365 | MS-SSIM: 0.9935 | PSNR: 37.4470
# iter: 11 | bpp: 1.3616 | MS-SSIM: 0.9941 | PSNR: 37.7665
# iter: 12 | bpp: 1.4866 | MS-SSIM: 0.9946 | PSNR: 38.0551
# iter: 13 | bpp: 1.6116 | MS-SSIM: 0.9949 | PSNR: 38.3468
# iter: 14 | bpp: 1.7367 | MS-SSIM: 0.9953 | PSNR: 38.6189
# iter: 15 | bpp: 1.8617 | MS-SSIM: 0.9956 | PSNR: 38.8590
# iter: 16 | bpp: 1.9867 | MS-SSIM: 0.9958 | PSNR: 39.0970
# iter: 17 | bpp: 2.0413 | MS-SSIM: 0.9955 | PSNR: 38.8499
# iter: 18 | bpp: 2.1273 | MS-SSIM: 0.9953 | PSNR: 38.8269
# iter: 19 | bpp: 2.2426 | MS-SSIM: 0.9954 | PSNR: 38.8621
# iter: 20 | bpp: 2.3497 | MS-SSIM: 0.9953 | PSNR: 38.8039
# iter: 21 | bpp: 2.4595 | MS-SSIM: 0.9953 | PSNR: 38.7858
# iter: 22 | bpp: 2.5813 | MS-SSIM: 0.9953 | PSNR: 38.7288
# iter: 23 | bpp: 2.6823 | MS-SSIM: 0.9951 | PSNR: 38.5610
# iter: 24 | bpp: 2.7958 | MS-SSIM: 0.9950 | PSNR: 38.4560
# iter: 25 | bpp: 2.9093 | MS-SSIM: 0.9948 | PSNR: 38.2888
# iter: 26 | bpp: 3.0226 | MS-SSIM: 0.9947 | PSNR: 38.1655
# iter: 27 | bpp: 3.1438 | MS-SSIM: 0.9945 | PSNR: 38.0377
# iter: 28 | bpp: 3.2532 | MS-SSIM: 0.9942 | PSNR: 37.8709
# iter: 29 | bpp: 3.3572 | MS-SSIM: 0.9937 | PSNR: 37.6261
# iter: 30 | bpp: 3.4747 | MS-SSIM: 0.9935 | PSNR: 37.3819
# iter: 31 | bpp: 3.5901 | MS-SSIM: 0.9931 | PSNR: 37.1321
# iter: 32 | bpp: 3.7028 | MS-SSIM: 0.9927 | PSNR: 36.9064
# iter: 01 | bpp: 0.1200 | MS-SSIM: 0.9492 | PSNR: 29.5982
# iter: 02 | bpp: 0.2451 | MS-SSIM: 0.9678 | PSNR: 30.7302
# iter: 03 | bpp: 0.3707 | MS-SSIM: 0.9745 | PSNR: 31.3091
# iter: 04 | bpp: 0.4957 | MS-SSIM: 0.9784 | PSNR: 31.7168
# iter: 05 | bpp: 0.6207 | MS-SSIM: 0.9814 | PSNR: 32.0622
# iter: 06 | bpp: 0.7458 | MS-SSIM: 0.9838 | PSNR: 32.3962
# iter: 07 | bpp: 0.8708 | MS-SSIM: 0.9858 | PSNR: 32.7050
# iter: 08 | bpp: 0.9958 | MS-SSIM: 0.9873 | PSNR: 32.9887
# iter: 09 | bpp: 1.1209 | MS-SSIM: 0.9887 | PSNR: 33.2732
# iter: 10 | bpp: 1.2459 | MS-SSIM: 0.9898 | PSNR: 33.5659
# iter: 11 | bpp: 1.3710 | MS-SSIM: 0.9908 | PSNR: 33.8519
# iter: 12 | bpp: 1.4960 | MS-SSIM: 0.9915 | PSNR: 34.1232
# iter: 13 | bpp: 1.6210 | MS-SSIM: 0.9921 | PSNR: 34.3646
# iter: 14 | bpp: 1.7461 | MS-SSIM: 0.9927 | PSNR: 34.6226
# iter: 15 | bpp: 1.8711 | MS-SSIM: 0.9932 | PSNR: 34.8664
# iter: 16 | bpp: 1.9961 | MS-SSIM: 0.9936 | PSNR: 35.0896
# iter: 17 | bpp: 2.0677 | MS-SSIM: 0.9932 | PSNR: 34.9210
# iter: 18 | bpp: 2.1683 | MS-SSIM: 0.9931 | PSNR: 34.9138
# iter: 19 | bpp: 2.2910 | MS-SSIM: 0.9931 | PSNR: 34.9515
# iter: 20 | bpp: 2.4106 | MS-SSIM: 0.9931 | PSNR: 34.9362
# iter: 21 | bpp: 2.5254 | MS-SSIM: 0.9931 | PSNR: 34.9676
# iter: 22 | bpp: 2.6505 | MS-SSIM: 0.9932 | PSNR: 34.9747
# iter: 23 | bpp: 2.7696 | MS-SSIM: 0.9931 | PSNR: 34.9084
# iter: 24 | bpp: 2.8919 | MS-SSIM: 0.9930 | PSNR: 34.8857
# iter: 25 | bpp: 3.0113 | MS-SSIM: 0.9929 | PSNR: 34.8084
# iter: 26 | bpp: 3.1339 | MS-SSIM: 0.9928 | PSNR: 34.7460
# iter: 27 | bpp: 3.2566 | MS-SSIM: 0.9927 | PSNR: 34.6954
# iter: 28 | bpp: 3.3779 | MS-SSIM: 0.9925 | PSNR: 34.6228
# iter: 29 | bpp: 3.4969 | MS-SSIM: 0.9921 | PSNR: 34.4968
# iter: 30 | bpp: 3.6218 | MS-SSIM: 0.9919 | PSNR: 34.3808
# iter: 31 | bpp: 3.7431 | MS-SSIM: 0.9917 | PSNR: 34.2534
# iter: 32 | bpp: 3.8639 | MS-SSIM: 0.9914 | PSNR: 34.1488
# iter: 01 | bpp: 0.1041 | MS-SSIM: 0.9609 | PSNR: 29.9325
# iter: 02 | bpp: 0.2277 | MS-SSIM: 0.9808 | PSNR: 31.5336
# iter: 03 | bpp: 0.3527 | MS-SSIM: 0.9859 | PSNR: 32.2330
# iter: 04 | bpp: 0.4777 | MS-SSIM: 0.9887 | PSNR: 32.7150
# iter: 05 | bpp: 0.6027 | MS-SSIM: 0.9904 | PSNR: 33.1205
# iter: 06 | bpp: 0.7278 | MS-SSIM: 0.9918 | PSNR: 33.5301
# iter: 07 | bpp: 0.8528 | MS-SSIM: 0.9930 | PSNR: 33.9485
# iter: 08 | bpp: 0.9778 | MS-SSIM: 0.9937 | PSNR: 34.3188
# iter: 09 | bpp: 1.1029 | MS-SSIM: 0.9944 | PSNR: 34.6755
# iter: 10 | bpp: 1.2279 | MS-SSIM: 0.9950 | PSNR: 35.0559
# iter: 11 | bpp: 1.3530 | MS-SSIM: 0.9954 | PSNR: 35.3842
# iter: 12 | bpp: 1.4780 | MS-SSIM: 0.9958 | PSNR: 35.6990
# iter: 13 | bpp: 1.6030 | MS-SSIM: 0.9961 | PSNR: 36.0173
# iter: 14 | bpp: 1.7281 | MS-SSIM: 0.9964 | PSNR: 36.3415
# iter: 15 | bpp: 1.8531 | MS-SSIM: 0.9966 | PSNR: 36.6330
# iter: 16 | bpp: 1.9781 | MS-SSIM: 0.9968 | PSNR: 36.9118
# iter: 17 | bpp: 2.0428 | MS-SSIM: 0.9966 | PSNR: 36.6418
# iter: 18 | bpp: 2.1358 | MS-SSIM: 0.9965 | PSNR: 36.6223
# iter: 19 | bpp: 2.2538 | MS-SSIM: 0.9965 | PSNR: 36.6451
# iter: 20 | bpp: 2.3647 | MS-SSIM: 0.9965 | PSNR: 36.6048
# iter: 21 | bpp: 2.4793 | MS-SSIM: 0.9965 | PSNR: 36.6197
# iter: 22 | bpp: 2.6013 | MS-SSIM: 0.9965 | PSNR: 36.6225
# iter: 23 | bpp: 2.7086 | MS-SSIM: 0.9964 | PSNR: 36.5055
# iter: 24 | bpp: 2.8278 | MS-SSIM: 0.9963 | PSNR: 36.4586
# iter: 25 | bpp: 2.9435 | MS-SSIM: 0.9962 | PSNR: 36.3132
# iter: 26 | bpp: 3.0566 | MS-SSIM: 0.9962 | PSNR: 36.2233
# iter: 27 | bpp: 3.1760 | MS-SSIM: 0.9961 | PSNR: 36.1414
# iter: 28 | bpp: 3.2871 | MS-SSIM: 0.9959 | PSNR: 36.0289
# iter: 29 | bpp: 3.3942 | MS-SSIM: 0.9957 | PSNR: 35.8538
# iter: 30 | bpp: 3.5133 | MS-SSIM: 0.9955 | PSNR: 35.6702
# iter: 31 | bpp: 3.6296 | MS-SSIM: 0.9953 | PSNR: 35.4632
# iter: 32 | bpp: 3.7419 | MS-SSIM: 0.9950 | PSNR: 35.3074
# iter: 01 | bpp: 0.0788 | MS-SSIM: 0.9587 | PSNR: 30.7216
# iter: 02 | bpp: 0.1740 | MS-SSIM: 0.9832 | PSNR: 33.3121
# iter: 03 | bpp: 0.2836 | MS-SSIM: 0.9876 | PSNR: 34.3021
# iter: 04 | bpp: 0.3979 | MS-SSIM: 0.9904 | PSNR: 34.8175
# iter: 05 | bpp: 0.5130 | MS-SSIM: 0.9916 | PSNR: 35.2621
# iter: 06 | bpp: 0.6283 | MS-SSIM: 0.9926 | PSNR: 35.5837
# iter: 07 | bpp: 0.7478 | MS-SSIM: 0.9935 | PSNR: 35.9200
# iter: 08 | bpp: 0.8670 | MS-SSIM: 0.9941 | PSNR: 36.2351
# iter: 09 | bpp: 0.9879 | MS-SSIM: 0.9947 | PSNR: 36.5415
# iter: 10 | bpp: 1.1106 | MS-SSIM: 0.9952 | PSNR: 36.8333
# iter: 11 | bpp: 1.2308 | MS-SSIM: 0.9955 | PSNR: 37.1097
# iter: 12 | bpp: 1.3510 | MS-SSIM: 0.9958 | PSNR: 37.3577
# iter: 13 | bpp: 1.4706 | MS-SSIM: 0.9960 | PSNR: 37.6064
# iter: 14 | bpp: 1.5883 | MS-SSIM: 0.9962 | PSNR: 37.8860
# iter: 15 | bpp: 1.7085 | MS-SSIM: 0.9964 | PSNR: 38.0965
# iter: 16 | bpp: 1.8272 | MS-SSIM: 0.9965 | PSNR: 38.2838
# iter: 17 | bpp: 1.8775 | MS-SSIM: 0.9964 | PSNR: 38.0099
# iter: 18 | bpp: 1.9647 | MS-SSIM: 0.9963 | PSNR: 37.9778
# iter: 19 | bpp: 2.0668 | MS-SSIM: 0.9963 | PSNR: 38.0209
# iter: 20 | bpp: 2.1664 | MS-SSIM: 0.9962 | PSNR: 37.9966
# iter: 21 | bpp: 2.2729 | MS-SSIM: 0.9962 | PSNR: 37.9895
# iter: 22 | bpp: 2.3809 | MS-SSIM: 0.9962 | PSNR: 37.9494
# iter: 23 | bpp: 2.4767 | MS-SSIM: 0.9961 | PSNR: 37.7984
# iter: 24 | bpp: 2.5786 | MS-SSIM: 0.9960 | PSNR: 37.7096
# iter: 25 | bpp: 2.6878 | MS-SSIM: 0.9959 | PSNR: 37.5665
# iter: 26 | bpp: 2.8028 | MS-SSIM: 0.9957 | PSNR: 37.4480
# iter: 27 | bpp: 2.9203 | MS-SSIM: 0.9956 | PSNR: 37.3269
# iter: 28 | bpp: 3.0279 | MS-SSIM: 0.9954 | PSNR: 37.1692
# iter: 29 | bpp: 3.1301 | MS-SSIM: 0.9951 | PSNR: 36.9580
# iter: 30 | bpp: 3.2373 | MS-SSIM: 0.9949 | PSNR: 36.7421
# iter: 31 | bpp: 3.3499 | MS-SSIM: 0.9947 | PSNR: 36.5150
# iter: 32 | bpp: 3.4631 | MS-SSIM: 0.9944 | PSNR: 36.3112
# iter: 01 | bpp: 0.0957 | MS-SSIM: 0.9443 | PSNR: 29.9401
# iter: 02 | bpp: 0.2092 | MS-SSIM: 0.9672 | PSNR: 31.4325
# iter: 03 | bpp: 0.3261 | MS-SSIM: 0.9749 | PSNR: 32.2451
# iter: 04 | bpp: 0.4481 | MS-SSIM: 0.9802 | PSNR: 32.7382
# iter: 05 | bpp: 0.5720 | MS-SSIM: 0.9833 | PSNR: 33.0850
# iter: 06 | bpp: 0.6964 | MS-SSIM: 0.9856 | PSNR: 33.4056
# iter: 07 | bpp: 0.8213 | MS-SSIM: 0.9878 | PSNR: 33.7201
# iter: 08 | bpp: 0.9464 | MS-SSIM: 0.9892 | PSNR: 33.9987
# iter: 09 | bpp: 1.0715 | MS-SSIM: 0.9904 | PSNR: 34.2602
# iter: 10 | bpp: 1.1965 | MS-SSIM: 0.9915 | PSNR: 34.5497
# iter: 11 | bpp: 1.3215 | MS-SSIM: 0.9923 | PSNR: 34.8115
# iter: 12 | bpp: 1.4465 | MS-SSIM: 0.9930 | PSNR: 35.0642
# iter: 13 | bpp: 1.5716 | MS-SSIM: 0.9936 | PSNR: 35.3227
# iter: 14 | bpp: 1.6966 | MS-SSIM: 0.9941 | PSNR: 35.6029
# iter: 15 | bpp: 1.8217 | MS-SSIM: 0.9946 | PSNR: 35.8453
# iter: 16 | bpp: 1.9467 | MS-SSIM: 0.9949 | PSNR: 36.0995
# iter: 17 | bpp: 2.0128 | MS-SSIM: 0.9946 | PSNR: 35.8672
# iter: 18 | bpp: 2.1067 | MS-SSIM: 0.9944 | PSNR: 35.8461
# iter: 19 | bpp: 2.2243 | MS-SSIM: 0.9945 | PSNR: 35.8744
# iter: 20 | bpp: 2.3359 | MS-SSIM: 0.9944 | PSNR: 35.8487
# iter: 21 | bpp: 2.4503 | MS-SSIM: 0.9945 | PSNR: 35.8714
# iter: 22 | bpp: 2.5720 | MS-SSIM: 0.9946 | PSNR: 35.8826
# iter: 23 | bpp: 2.6789 | MS-SSIM: 0.9945 | PSNR: 35.8037
# iter: 24 | bpp: 2.7976 | MS-SSIM: 0.9944 | PSNR: 35.7588
# iter: 25 | bpp: 2.9136 | MS-SSIM: 0.9943 | PSNR: 35.6512
# iter: 26 | bpp: 3.0265 | MS-SSIM: 0.9943 | PSNR: 35.5769
# iter: 27 | bpp: 3.1444 | MS-SSIM: 0.9942 | PSNR: 35.5051
# iter: 28 | bpp: 3.2559 | MS-SSIM: 0.9940 | PSNR: 35.4198
# iter: 29 | bpp: 3.3627 | MS-SSIM: 0.9938 | PSNR: 35.2828
# iter: 30 | bpp: 3.4816 | MS-SSIM: 0.9937 | PSNR: 35.1365
# iter: 31 | bpp: 3.5985 | MS-SSIM: 0.9935 | PSNR: 34.9663
# iter: 32 | bpp: 3.7102 | MS-SSIM: 0.9933 | PSNR: 34.8284
# iter: 01 | bpp: 0.1097 | MS-SSIM: 0.9651 | PSNR: 30.0481
# iter: 02 | bpp: 0.2340 | MS-SSIM: 0.9792 | PSNR: 31.4333
# iter: 03 | bpp: 0.3587 | MS-SSIM: 0.9840 | PSNR: 32.1470
# iter: 04 | bpp: 0.4837 | MS-SSIM: 0.9867 | PSNR: 32.6289
# iter: 05 | bpp: 0.6087 | MS-SSIM: 0.9886 | PSNR: 33.0466
# iter: 06 | bpp: 0.7338 | MS-SSIM: 0.9900 | PSNR: 33.4416
# iter: 07 | bpp: 0.8588 | MS-SSIM: 0.9915 | PSNR: 33.8263
# iter: 08 | bpp: 0.9838 | MS-SSIM: 0.9923 | PSNR: 34.1520
# iter: 09 | bpp: 1.1089 | MS-SSIM: 0.9932 | PSNR: 34.4652
# iter: 10 | bpp: 1.2339 | MS-SSIM: 0.9939 | PSNR: 34.7878
# iter: 11 | bpp: 1.3590 | MS-SSIM: 0.9944 | PSNR: 35.0853
# iter: 12 | bpp: 1.4840 | MS-SSIM: 0.9949 | PSNR: 35.3516
# iter: 13 | bpp: 1.6090 | MS-SSIM: 0.9952 | PSNR: 35.6214
# iter: 14 | bpp: 1.7341 | MS-SSIM: 0.9955 | PSNR: 35.8909
# iter: 15 | bpp: 1.8591 | MS-SSIM: 0.9959 | PSNR: 36.1532
# iter: 16 | bpp: 1.9841 | MS-SSIM: 0.9961 | PSNR: 36.3907
# iter: 17 | bpp: 2.0520 | MS-SSIM: 0.9958 | PSNR: 36.1981
# iter: 18 | bpp: 2.1475 | MS-SSIM: 0.9958 | PSNR: 36.1901
# iter: 19 | bpp: 2.2693 | MS-SSIM: 0.9958 | PSNR: 36.2330
# iter: 20 | bpp: 2.3820 | MS-SSIM: 0.9958 | PSNR: 36.2150
# iter: 21 | bpp: 2.4960 | MS-SSIM: 0.9958 | PSNR: 36.2327
# iter: 22 | bpp: 2.6200 | MS-SSIM: 0.9958 | PSNR: 36.2355
# iter: 23 | bpp: 2.7337 | MS-SSIM: 0.9958 | PSNR: 36.1543
# iter: 24 | bpp: 2.8536 | MS-SSIM: 0.9957 | PSNR: 36.1101
# iter: 25 | bpp: 2.9697 | MS-SSIM: 0.9956 | PSNR: 36.0053
# iter: 26 | bpp: 3.0865 | MS-SSIM: 0.9956 | PSNR: 35.9325
# iter: 27 | bpp: 3.2081 | MS-SSIM: 0.9955 | PSNR: 35.8607
# iter: 28 | bpp: 3.3228 | MS-SSIM: 0.9953 | PSNR: 35.7510
# iter: 29 | bpp: 3.4358 | MS-SSIM: 0.9951 | PSNR: 35.5860
# iter: 30 | bpp: 3.5557 | MS-SSIM: 0.9950 | PSNR: 35.4193
# iter: 31 | bpp: 3.6723 | MS-SSIM: 0.9948 | PSNR: 35.2517
# iter: 32 | bpp: 3.7889 | MS-SSIM: 0.9946 | PSNR: 35.1168
# iter: 01 | bpp: 0.1072 | MS-SSIM: 0.9704 | PSNR: 30.3888
# iter: 02 | bpp: 0.2290 | MS-SSIM: 0.9859 | PSNR: 32.6929
# iter: 03 | bpp: 0.3494 | MS-SSIM: 0.9916 | PSNR: 34.8241
# iter: 04 | bpp: 0.4739 | MS-SSIM: 0.9934 | PSNR: 35.8935
# iter: 05 | bpp: 0.5984 | MS-SSIM: 0.9946 | PSNR: 36.5984
# iter: 06 | bpp: 0.7234 | MS-SSIM: 0.9955 | PSNR: 37.1644
# iter: 07 | bpp: 0.8484 | MS-SSIM: 0.9961 | PSNR: 37.6735
# iter: 08 | bpp: 0.9731 | MS-SSIM: 0.9965 | PSNR: 38.0662
# iter: 09 | bpp: 1.0983 | MS-SSIM: 0.9969 | PSNR: 38.4012
# iter: 10 | bpp: 1.2233 | MS-SSIM: 0.9973 | PSNR: 38.7483
# iter: 11 | bpp: 1.3484 | MS-SSIM: 0.9975 | PSNR: 39.0427
# iter: 12 | bpp: 1.4734 | MS-SSIM: 0.9977 | PSNR: 39.2920
# iter: 13 | bpp: 1.5984 | MS-SSIM: 0.9978 | PSNR: 39.5551
# iter: 14 | bpp: 1.7235 | MS-SSIM: 0.9980 | PSNR: 39.7691
# iter: 15 | bpp: 1.8485 | MS-SSIM: 0.9981 | PSNR: 39.9592
# iter: 16 | bpp: 1.9735 | MS-SSIM: 0.9982 | PSNR: 40.1330
# iter: 17 | bpp: 2.0227 | MS-SSIM: 0.9981 | PSNR: 39.9557
# iter: 18 | bpp: 2.1108 | MS-SSIM: 0.9980 | PSNR: 39.9169
# iter: 19 | bpp: 2.2241 | MS-SSIM: 0.9980 | PSNR: 39.9862
# iter: 20 | bpp: 2.3305 | MS-SSIM: 0.9980 | PSNR: 39.9469
# iter: 21 | bpp: 2.4387 | MS-SSIM: 0.9980 | PSNR: 39.9160
# iter: 22 | bpp: 2.5570 | MS-SSIM: 0.9980 | PSNR: 39.8297
# iter: 23 | bpp: 2.6540 | MS-SSIM: 0.9980 | PSNR: 39.6308
# iter: 24 | bpp: 2.7601 | MS-SSIM: 0.9979 | PSNR: 39.4666
# iter: 25 | bpp: 2.8705 | MS-SSIM: 0.9979 | PSNR: 39.2907
# iter: 26 | bpp: 2.9824 | MS-SSIM: 0.9978 | PSNR: 39.1424
# iter: 27 | bpp: 3.0998 | MS-SSIM: 0.9977 | PSNR: 38.9381
# iter: 28 | bpp: 3.2056 | MS-SSIM: 0.9976 | PSNR: 38.6889
# iter: 29 | bpp: 3.3053 | MS-SSIM: 0.9975 | PSNR: 38.3525
# iter: 30 | bpp: 3.4148 | MS-SSIM: 0.9973 | PSNR: 38.0258
# iter: 31 | bpp: 3.5298 | MS-SSIM: 0.9972 | PSNR: 37.7129
# iter: 32 | bpp: 3.6419 | MS-SSIM: 0.9970 | PSNR: 37.4048
# iter: 01 | bpp: 0.1223 | MS-SSIM: 0.9354 | PSNR: 29.9153
# iter: 02 | bpp: 0.2488 | MS-SSIM: 0.9594 | PSNR: 31.1085
# iter: 03 | bpp: 0.3743 | MS-SSIM: 0.9678 | PSNR: 31.7479
# iter: 04 | bpp: 0.4993 | MS-SSIM: 0.9732 | PSNR: 32.2429
# iter: 05 | bpp: 0.6243 | MS-SSIM: 0.9773 | PSNR: 32.6558
# iter: 06 | bpp: 0.7494 | MS-SSIM: 0.9803 | PSNR: 33.0357
# iter: 07 | bpp: 0.8744 | MS-SSIM: 0.9831 | PSNR: 33.3646
# iter: 08 | bpp: 0.9994 | MS-SSIM: 0.9850 | PSNR: 33.6759
# iter: 09 | bpp: 1.1245 | MS-SSIM: 0.9865 | PSNR: 33.9449
# iter: 10 | bpp: 1.2495 | MS-SSIM: 0.9880 | PSNR: 34.2368
# iter: 11 | bpp: 1.3746 | MS-SSIM: 0.9890 | PSNR: 34.4885
# iter: 12 | bpp: 1.4996 | MS-SSIM: 0.9900 | PSNR: 34.7235
# iter: 13 | bpp: 1.6246 | MS-SSIM: 0.9907 | PSNR: 34.9576
# iter: 14 | bpp: 1.7497 | MS-SSIM: 0.9914 | PSNR: 35.1865
# iter: 15 | bpp: 1.8747 | MS-SSIM: 0.9920 | PSNR: 35.4013
# iter: 16 | bpp: 1.9997 | MS-SSIM: 0.9925 | PSNR: 35.6108
# iter: 17 | bpp: 2.0705 | MS-SSIM: 0.9921 | PSNR: 35.4141
# iter: 18 | bpp: 2.1718 | MS-SSIM: 0.9919 | PSNR: 35.4174
# iter: 19 | bpp: 2.2956 | MS-SSIM: 0.9921 | PSNR: 35.4554
# iter: 20 | bpp: 2.4137 | MS-SSIM: 0.9920 | PSNR: 35.4420
# iter: 21 | bpp: 2.5307 | MS-SSIM: 0.9921 | PSNR: 35.4520
# iter: 22 | bpp: 2.6536 | MS-SSIM: 0.9922 | PSNR: 35.4407
# iter: 23 | bpp: 2.7706 | MS-SSIM: 0.9921 | PSNR: 35.3689
# iter: 24 | bpp: 2.8920 | MS-SSIM: 0.9921 | PSNR: 35.3425
# iter: 25 | bpp: 3.0116 | MS-SSIM: 0.9920 | PSNR: 35.2698
# iter: 26 | bpp: 3.1334 | MS-SSIM: 0.9919 | PSNR: 35.2067
# iter: 27 | bpp: 3.2572 | MS-SSIM: 0.9917 | PSNR: 35.1496
# iter: 28 | bpp: 3.3765 | MS-SSIM: 0.9915 | PSNR: 35.0723
# iter: 29 | bpp: 3.4953 | MS-SSIM: 0.9913 | PSNR: 34.9503
# iter: 30 | bpp: 3.6172 | MS-SSIM: 0.9911 | PSNR: 34.8281
# iter: 31 | bpp: 3.7388 | MS-SSIM: 0.9908 | PSNR: 34.6907
# iter: 32 | bpp: 3.8592 | MS-SSIM: 0.9906 | PSNR: 34.5768

# %%
results = []
for datas in results_dict.values():
    data = [datas[0][0]]

    bpp_values = [r[1] for r in datas]
    ms_ssim_scores = [r[2] for r in datas]
    psnr_scores = [r[3] for r in datas]
    
    data.append(sum(bpp_values) / len(bpp_values))
    data.append(sum(ms_ssim_scores) / len(ms_ssim_scores))
    data.append(sum(psnr_scores) / len(psnr_scores))

    results.append(data)

# DataFrame 생성
df = pd.DataFrame(results, columns=['quality', 'bpp', 'MS-SSIM', 'PSNR'])

# 엑셀 파일로 저장
excel_path = f'/home/vision/models/AdvancedDigitalSignalProcessingCourse-FinalTermProject/data/kodim/results_rnn.xlsx'
df.to_excel(excel_path, index=False)
    
    # print(f'{sampling} 샘플링 팩터에 대한 결과가 {excel_path}에 저장되었습니다.')
# JPEG 폴더의 모든 파일에 대해 MS-SSIM 계산


# for file_name in os.listdir(jpeg_folder):
#     if file_name.lower().endswith('.jpeg'):
#         # JPEG 파일 경로
#         jpeg_path = os.path.join(jpeg_folder, file_name)
        
#         # 원본 PNG 파일 경로
#         original_file_name = file_name.split('_')[0] + '.png'
#         original_path = os.path.join(png_folder, original_file_name)
        
#         # 이미지 열기
#         with Image.open(jpeg_path) as img_jpeg, Image.open(original_path) as img_original:
#             # 이미지를 Tensor로 변환
#             img_jpeg = torch.from_numpy(np.array(img_jpeg)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
#             img_original = torch.from_numpy(np.array(img_original)).permute(2, 0, 1).unsqueeze(0).float() / 255.0
            
#             # MS-SSIM 계산
#             score = ms_ssim(img_jpeg, img_original, data_range=1.0).item()
            
#             # 파일 크기 계산 (bytes -> bits)
#             jpeg_size = os.path.getsize(jpeg_path) * 8
#             bpp = jpeg_size / (img_jpeg.shape[2] * img_jpeg.shape[3])
            
#             # 결과 저장
#             results.append((bpp, score, file_name))

# # 결과를 bpp 기준으로 정렬
# results.sort()

# # bpp와 MS-SSIM 스코어 추출
# bpp_values = [r[0] for r in results]
# ms_ssim_scores = [r[1] for r in results]

# # 결과 출력
# for bpp, score, file_name in results:
#     print(f'파일: {file_name}, bpp: {bpp:.4f}, MS-SSIM: {score:.4f}')

# # 그래프 그리기
# plt.figure(figsize=(10, 6))
# plt.plot(bpp_values, ms_ssim_scores, marker='o')
# plt.xlabel('Bits Per Pixel (bpp)')
# plt.ylabel('MS-SSIM Score')
# plt.title('bpp vs MS-SSIM Score')
# plt.grid(True)
# plt.show()
